# %%
import numpy
arr=numpy.random.rand(5,4,4)
arr
# Out:
# array([[[0.32048156, 0.57684649, 0.18693459, 0.3197817 ],
#         [0.70914   , 0.98250744, 0.98108563, 0.43900457],
#         [0.62634457, 0.32990252, 0.14886214, 0.02300804],
#         [0.65364215, 0.90505408, 0.67536833, 0.16521015]],
#
#        [[0.91618251, 0.00627066, 0.78721966, 0.04918665],
#         [0.09340865, 0.77261904, 0.2756478 , 0.192182  ],
#         [0.92138872, 0.30869987, 0.3583682 , 0.35353284],
#         [0.17080776, 0.19371392, 0.74596531, 0.01529684]],
#
#        [[0.48051642, 0.71428953, 0.78055045, 0.25438424],
#         [0.96795711, 0.37743709, 0.92922309, 0.35185991],
#         [0.99175802, 0.37784476, 0.64552461, 0.4777137 ],
#         [0.7290458 , 0.59211763, 0.88713376, 0.92442286]],
#
#        [[0.58700418, 0.85099679, 0.78267997, 0.62245965],
#         [0.59396807, 0.73530273, 0.0939833 , 0.18986626],
#         [0.45195276, 0.02078466, 0.50091977, 0.20812602],
#         [0.84533677, 0.38664973, 0.33665382, 0.66085872]],
#
# ...

# %%
arr[1]
arr[1:,1:2]
# Out:
# array([[[0.09340865, 0.77261904, 0.2756478 , 0.192182  ]],
#
#        [[0.96795711, 0.37743709, 0.92922309, 0.35185991]],
#
#        [[0.59396807, 0.73530273, 0.0939833 , 0.18986626]],
#
#        [[0.49510891, 0.41648822, 0.46373468, 0.55445146]]])
